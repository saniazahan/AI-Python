# %% [markdown]
# #Custom Apriltag image classifier
# Author: Sania Zahan Date: 17/11/2025

# %% [markdown]
# #Organize Your Dataset:
# Create a main directory for your dataset. Inside this main directory, create subdirectories, where each subdirectory represents a class, and contains the images belonging to that class.
#
# Apriltag images: https://github.com/AprilRobotics/apriltag-imgs
#
# Tags and corresponding labels:
#
# tag16h5 -> Left; tag25h9 -> Right;
#
# tag36h11 -> Forward; tagCircle21h7 -> Backward
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Download and unzip data
# Dataset link: https://github.com/saniazahan/AI-Python/blob/main/Dataset/apriltag_dataset.zip

# %%
# !unzip apriltag_dataset.zip
# Out:
# Archive:  apriltag_dataset.zip
#    creating: apriltag_dataset_v2/
#    creating: apriltag_dataset_v2/right/
#    creating: apriltag_dataset_v2/backward/
#    creating: apriltag_dataset_v2/left/
#    creating: apriltag_dataset_v2/stop/
#    creating: apriltag_dataset_v2/flashrgb/
#    creating: apriltag_dataset_v2/display/
#    creating: apriltag_dataset_v2/flashled/
#    creating: apriltag_dataset_v2/forward/
#    creating: apriltag_dataset_v2/playsound/
#   inflating: apriltag_dataset_v2/right/tag36_11_00558.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00564.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00570.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00571.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00565.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00559.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00573.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00567.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00566.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00572.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00562.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00563.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00561.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00575.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00549.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00548.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00574.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00560.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00507.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00513.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00512.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00506.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00538.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00510.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00504.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00505.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00511.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00539.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00515.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00501.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00529.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00528.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00500.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00514.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00502.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00516.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00517.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00503.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00526.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00532.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00533.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00527.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00519.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00531.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00525.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00524.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00530.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00518.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00534.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00520.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00508.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00509.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00521.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00535.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00523.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00537.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00536.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00522.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00545.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00551.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00550.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00544.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00552.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00546.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00547.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00553.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00557.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00543.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00542.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00556.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00540.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00554.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00568.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00569.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00555.png
#   inflating: apriltag_dataset_v2/right/tag36_11_00541.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00028.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00000.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00014.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00015.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00001.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00029.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00017.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00003.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00002.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00016.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00012.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00006.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00007.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00013.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00005.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00011.png
#   inflating: apriltag_dataset_v2/backward/tag36_11_00038.png
png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00299.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00272.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00312.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00306.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00310.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00304.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00338.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00270.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00271.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00339.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00305.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00311.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00308.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00334.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00320.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00283.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00297.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00296.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00282.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00321.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00335.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00309.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00323.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00337.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00294.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00280.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00281.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00295.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00336.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00322.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00326.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00332.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00291.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00285.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00284.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00290.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00333.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00327.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00331.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00325.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00319.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00279.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00286.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00292.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00293.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00287.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00278.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00318.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00324.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00330.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00343.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00342.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00340.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00341.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00345.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00344.png
#   inflating: apriltag_dataset_v2/forward/tag36_11_00346.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00438.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00439.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00429.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00428.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00473.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00467.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00498.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00499.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00466.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00472.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00458.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00464.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00470.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00471.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00465.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00459.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00461.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00475.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00449.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00448.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00474.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00460.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00476.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00462.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00489.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00488.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00463.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00477.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00452.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00446.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00491.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00485.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00484.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00490.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00447.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00453.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00479.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00445.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00451.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00486.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00492.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00493.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00487.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00450.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00444.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00478.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00440.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00454.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00468.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00483.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00497.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00496.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00482.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00469.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00455.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00441.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00457.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00443.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00494.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00480.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00481.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00495.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00442.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00456.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00431.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00425.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00424.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00430.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00426.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00432.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00433.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00427.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00437.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00436.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00434.png
#   inflating: apriltag_dataset_v2/playsound/tag36_11_00435.png

# %% [markdown]
# #Import necessary libraries

# %%
import tensorflow as tf  # Main TensorFlow library for building and training machine learning models
from tensorflow import keras  # High-level API within TensorFlow for simplifying neural network creation
from tensorflow.keras import layers  # Provides building blocks like Dense, Conv2D, etc. for model architecture
import matplotlib.pyplot as plt  # Plotting library used for visualizing data, metrics, and results
from tensorflow.keras.applications import ResNet50 # Pretrained ResNet50 model for transfer learning and feature extraction

# %% [markdown]
# #Load the Dataset with image_dataset_from_directory:
#
# Keras's image_dataset_from_directory utility is designed for this purpose.

# %%
# Define parameters for loading the dataset
IMG_HEIGHT = 224    # VGG16 default input size
IMG_WIDTH  = 224
BATCH_SIZE = 32

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
    'apriltag_dataset_v2', # Path to your main dataset folder
    labels='inferred',
    label_mode='int', # 'int' for integer-encoded labels (0, 1, 2...), 'binary' for 0/1, 'categorical' for one-hot
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    interpolation='nearest',
    batch_size=BATCH_SIZE,
    shuffle=True,
    validation_split=0.2, # Optional: split a portion for validation
    subset='training',
    seed=123 # For reproducible split
)

# Load the validation data (if validation_split was used)
val_ds = tf.keras.utils.image_dataset_from_directory(
    'apriltag_dataset_v2',
    labels='inferred',
    label_mode='int',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    interpolation='nearest',
    batch_size=BATCH_SIZE,
    shuffle=False, # No need to shuffle validation data
    validation_split=0.2,
    subset='validation',
    seed=123
)

# Get class names
class_names = train_ds.class_names
print(f"Class names: {class_names}")
# Out:
# Found 690 files belonging to 9 classes.
# Using 552 files for training.
# Found 690 files belonging to 9 classes.
# Using 138 files for validation.
# Class names: ['backward', 'display', 'flashled', 'flashrgb', 'forward', 'left', 'playsound', 'right', 'stop']

# %% [markdown]
# #Prepare the Data for Training:
# Optimize performance by prefetching and caching.

# %%
AUTOTUNE = tf.data.AUTOTUNE  # Let TensorFlow automatically choose the best speed settings

# Make loading the training data faster by keeping it ready in memory
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Make loading the testing/validation data faster the same way
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #Build and Train Your Model:
# Define a Convolutional Neural Network (CNN) and train it.
#
# Imagine a Conv2D layer as the model searching an image for specific clues.
#
# It analyses a small area (the 'kernel') to scan over the image, looking for patterns like edges or shapes.
#
# When it finds a pattern, it marks it down. This process creates a new, simplified image that highlights where those patterns were found.

# %%
num_classes = len(class_names) # Count how many different kinds of images we have

# Load ResNet50 without top classifier
resnet_base = ResNet50(
    weights="imagenet",        # Use the knowledge it learned from millions of images, imagenet is one of the largest image dataset created so far
    include_top=False,         # Don't use its old final layers; we'll add our own
    input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)  # Size of our pictures
)
# Freeze convolutional layers (recommended for transfer learning)
resnet_base.trainable = False

model = keras.Sequential([
    layers.Rescaling(1./255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),

    # Pretrained convolutional feature extractor, Use ResNET as a feature finder (it knows how to spot edges, shapes, patterns)
    resnet_base,

    layers.Flatten(),                          # flatten the feature maps, turn the 2D features into a 1D list
    layers.Dense(128, activation='relu'),      # A normal learning layer that helps make decisions
    layers.Dense(num_classes, activation='softmax') # Final layer that chooses which class the image belongs to (gives us the probability values)
])

model.summary()

# Tell the model:
# - how to improve itself (optimizer)
# - how to measure mistakes (loss)
# - what score to show us during training (metrics)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), # from_logits=False if using softmax
              metrics=['accuracy'])
# Softmax if the raw scores of a tag prediction were:
# Left: 2.5
# Right: 1.0
# Forward: 3.0
# Backward: 0.5

# Softmax would convert them into something like:
# Left: 20%
# Right: 5%
# Forward: 70%
# Backward: 5%

model.summary()

epochs = 10 # Train the model for 10 rounds

# Train the model using our training pictures, and check progress with the validation pictures
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    12,845,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,434,057 (138.98 MB)
#  Trainable params: 12,846,345 (49.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    12,845,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,434,057 (138.98 MB)
#  Trainable params: 12,846,345 (49.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 149s 8s/step - accuracy: 0.0985 - loss: 17.1698 - val_accuracy: 0.4710 - val_loss: 1.2315
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 120s 7s/step - accuracy: 0.2218 - loss: 2.3577 - val_accuracy: 0.5507 - val_loss: 1.3607
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 118s 7s/step - accuracy: 0.2639 - loss: 1.9535 - val_accuracy: 0.6232 - val_loss: 1.2359
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 142s 7s/step - accuracy: 0.3193 - loss: 1.8460 - val_accuracy: 0.7754 - val_loss: 1.0329
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 119s 7s/step - accuracy: 0.3403 - loss: 1.8036 - val_accuracy: 0.6884 - val_loss: 1.0761
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 138s 8s/step - accuracy: 0.3871 - loss: 1.7773 - val_accuracy: 0.7826 - val_loss: 0.9664
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 118s 7s/step - accuracy: 0.3935 - loss: 1.7376 - val_accuracy: 0.6812 - val_loss: 0.9801
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 117s 7s/step - accuracy: 0.3790 - loss: 1.7070 - val_accuracy: 0.7101 - val_loss: 0.9332
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 118s 7s/step - accuracy: 0.4137 - loss: 1.6636 - val_accuracy: 0.6884 - val_loss: 0.9461
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 117s 7s/step - accuracy: 0.4020 - loss: 1.6263 - val_accuracy: 0.6812 - val_loss: 0.9545

# %%
# === Save the trained Keras model ===

model.save("apriltag_model.keras")   # Modern recommended format

# Optional: Save also to H5 if you want broader compatibility
# model.save("apriltag_model.h5")

print("Model saved successfully as apriltag_model.keras!")
# Out:
# Model saved successfully as apriltag_model.keras!

# %%
# Get the history data
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Plot accuracy
plt.figure(figsize=(7, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training')
plt.plot(epochs, val_acc, label='Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training')
plt.plot(epochs, val_loss, label='Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluate and Predict:
# Evaluate the model's performance and make predictions on new images.

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_ds)
print(f"Validation accuracy: {accuracy}")

# %%
import os
import random
all_images = []
for root, dirs, files in os.walk('apriltag_dataset_v2'):
    for file in files:
        if file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            all_images.append(os.path.join(root, file))

# Pick 10 random images from the list
selected = random.sample(all_images, 10)

# Test each selected image with the trained model
for image_path in selected:
  actual_label = image_path.split('/')[1]   # Get the real label from its folder name

  # Load the image and make it the correct size for the model
  img = tf.keras.utils.load_img(image_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
  img_array = tf.keras.utils.img_to_array(img)  # Convert to numbers the model understands
  img_array = tf.expand_dims(img_array, 0)      # Models expect a batch, so we add one extra dimension

  predictions = model.predict(img_array)        # Ask the model what it thinks the image is
  score = tf.nn.softmax(predictions[0])         # Turn the raw scores into percentages

  # Print the model’s guess and how sure it is, plus the real answer
  print(f"This image most likely belongs to {class_names[tf.argmax(score)]} "
        f"with a {100 * tf.reduce_max(score):.2f}% confidence. "
        f"Acutal label is {actual_label}")
